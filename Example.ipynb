# %% [markdown]
# ## Introduction
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec posuere urna et turpis feugiat, in ornare dui rutrum. Sed id gravida risus. Nam scelerisque quam vitae ante elementum pharetra non viverra lectus. Mauris convallis dui sed ultricies blandit. Curabitur non tempor orci. Fusce nisl neque, sodales et nunc nec, porta dapibus nibh. Donec nibh ligula, consectetur vel tristique et, cursus non ex.

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use(['tableau'])

plt.title('A Histogram')
sns.distplot(np.random.normal(size=100))

# %% [markdown]
# ## Theory
#
# Maecenas sed efficitur tortor. Aenean vel tellus sit amet erat vestibulum faucibus molestie ut augue. Nullam at sapien diam. Duis sit amet consequat nibh. Mauris mollis maximus vestibulum. Vestibulum lorem enim, facilisis eu facilisis eget, placerat rutrum augue. Integer eget ligula molestie, bibendum lectus vitae, viverra nibh.
#
#
#
# <span class='notes'>Here are some notes about the theory.</span>

# %%
iris = sns.load_dataset("iris")

plt.title('Iris Data (Box Plot)')
sns.boxplot(data=iris, orient="v");

# %% [markdown]
# ### Ideas
#
# Vestibulum placerat congue vulputate. Mauris massa lorem, ornare non vehicula id, molestie a leo. Maecenas posuere varius lorem sed rutrum. Phasellus vehicula commodo eros id sollicitudin. Quisque vitae augue eros. Praesent vitae pellentesque purus. Aliquam erat volutpat. Aliquam tincidunt, sapien vitae faucibus luctus, eros ex ultrices sapien, vitae commodo risus est at nulla. Pellentesque leo tortor, pulvinar quis ligula vel, ornare lobortis metus. Fusce non ligula aliquam, pharetra nisi ac, aliquam sapien.
#
# ### More Ideas
#
# Integer nisi elit, ultrices nec gravida eget, gravida ut quam. Quisque porta suscipit malesuada. Ut venenatis leo in felis iaculis, ut tempor lorem blandit. Nam volutpat enim nisl, tempor eleifend orci consectetur a. Quisque eleifend auctor metus, ac fermentum quam condimentum sed. Suspendisse ac consectetur neque, at aliquam nisi. Phasellus ut ipsum dui. In ac tristique est. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aliquam porttitor tempus libero a lacinia.

# %%
plt.title('Iris Data (Violin Plot)')
sns.violinplot(x=iris.species, y=iris.sepal_length);
